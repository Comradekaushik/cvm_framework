# %%
import pandas as pd

# %%
set_subs = set(pd.read_parquet('../datasrc/data/features/20251101.parquet').iloc[:,0])

# %%
with open("../all_subs_id/subs_id.csv","w") as mysink:
    for id in set_subs:
        print(id,file = mysink)
